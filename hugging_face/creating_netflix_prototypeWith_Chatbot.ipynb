# %% [markdown]
# Netflix Prototype – Anti-Hallucination Plan
# (we’ll tick every box before moving on)
#
# 0. Guardrails
#    - One branch per step, commit after each.
#    - No feature creep without adding it to the list below and ticking off a previous one.
#    - If either of us mentions a new idea, we park it in “Future” until current step is done.
#
# 1. Skeleton (✅ = done)
#    1.1 Pick stack: React+Vite+Tailwind (no back-end)
#    1.2 Repo created & pushed to GitHub
#    1.3 Folder structure agreed:
#
#        src/
#        ├── components/Navbar.jsx
#        ├── components/Row.jsx
#        ├── components/Modal.jsx
#        ├── pages/Landing.jsx
#        ├── pages/Browse.jsx
#        ├── data/movies.json
#        └── App.jsx
#
# 2. Static Data (movies.json)
#    2.1 40 items, 5 genres, each: id, title, img, banner, desc, maturityRating, duration, videoURL (trailer)
#    2.2 JSON validated with jsonlint → commit
#
# 3. Routing
#    3.1 Install react-router-dom
#    3.2 Routes: / → Landing, /browse → Browse, /player/:id → Player
#    3.3 Smoke-test every route
#
# 4. Layout & Styling Tokens
#    4.1 Tailwind config: Netflix black (#141414), red (#E50914), gradient overlays
#    4.2 Responsive 12-col grid, breakpoint sm/md/lg
#    4.3 Global CSS reset & font (Netflix Sans or fallback)
#
# 5. Components (strict one-way data flow)
#    5.1 Navbar (logo, avatar, search placeholder)
#    5.2 Row → maps movies.json by genre, horizontal scroll, snap points
#    5.3 Tile → hover scale 1.08, show muted title, onClick open Modal
#    5.4 Modal → portal, backdrop blur, shows banner, synopsis, Play button (links to Player)
#    5.5 Player → full-screen iframe, back button returns to Browse
#
# 6. State Management
#    6.1 useContext for “selectedMovie” (avoids prop-drill)
#    6.2 Custom hook useModalToggle → open/close
#
# 7. Interactions & UX Polish
#    7.1 Keyboard nav: left/right arrows inside Row
#    7.2 Lazy-load images (native loading=“lazy”)
#    7.3 Skeleton loaders while images fetch
#
# 8. Video Playback Simulation
#    8.1 Use 30-sec trailer MP4s (royalty-free)
#    8.2 Controls: play/pause, mute, 10-s skip, progress bar (HTML5 video)
#    8.3 Auto-exit to Browse when video ends
#
# 9. Performance Budget
#    9.1 Lighthouse score ≥ 90 on local build
#    9.2 Bundle ≤ 250 kB gzipped (Vite split chunks)
#
# 10. Deploy & Share
#     10.1 Netlify site linked to repo main branch
#     10.2 Environment var: VITE_API_URL (placeholder for future backend)
#     10.3 README: live demo link + how to clone & run
#
# Future (parked)
# - Auth (Firebase)
# - My List (persist to localStorage)
# - Search filter
# - Admin page to edit movies.json
#
# We’ll quote the step number in every reply so we never drift.
# Reply with “Step 1.1 go” when you’re ready and I’ll generate the repo + Vite starter.
